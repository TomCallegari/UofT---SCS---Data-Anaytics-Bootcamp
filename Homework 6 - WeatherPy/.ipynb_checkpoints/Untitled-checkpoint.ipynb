# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from requests import get
from time import sleep
from pprint import pprint
import json

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
city_iter = [str(i) for i in cities]

city_count = 0
city_data = pd.DataFrame()

for city in city_iter:
    
    response = get('http://api.openweathermap.org/data/2.5/weather?q='
                  + city
                  + '&APPID='
                  + api_key).json()
    
    sleep(1.5)
        
    try:
        
        city_dict = {
        'city_id': response['id'],
        'name': response['name'],
        'country': response['sys']['country'],
        'longitude': response['coord']['lon'],
        'latitude': response['coord']['lat'],
        'humidity': response['main']['humidity'],
        'temperature': response['main']['temp'],
        'wind_speed': response['wind']['speed']
        }
    
        temp_df = pd.DataFrame(city_dict, index = ['city']).set_index('city_id')    
        city_data = pd.concat([city_data, temp_df])
        
        city_count += 1
        city_name = city_dict['name']    
            
        city_dict = {}
        
    except KeyError as e:
        
        print(f'Skipping city ... : KeyError: {e} not found.') 
    
    print(f'Accessing city # {city_count} | {city_name}')
# Out:
# Accessing city # 1: Hilo
# Accessing city # 2: Ushuaia
# Accessing city # 3: Streator
# Accessing city # 4: East London
# Accessing city # 5: Severnoye
# Accessing city # 6: San Cristobal
# Accessing city # 7: Castro
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 7: Castro
# Accessing city # 8: Tiksi
# Accessing city # 9: Atuona
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 9: Atuona
# Accessing city # 10: Fortuna
# Accessing city # 11: Kapaa
# Accessing city # 12: Hithadhoo
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 12: Hithadhoo
# Accessing city # 13: Bethel
# Accessing city # 14: Alihe
# Accessing city # 15: Kaitangata
# Accessing city # 16: Cape Town
# Accessing city # 17: Grindavik
# Accessing city # 18: Leningradskiy
# Accessing city # 19: Anchorage
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 19: Anchorage
# Accessing city # 20: Inirida
# Accessing city # 21: Portland
# Accessing city # 22: Russell
# Accessing city # 23: Kodiak
# Accessing city # 24: Albany
# Accessing city # 25: Abeche
# Accessing city # 26: Kavieng
# Accessing city # 27: Vaini
# Accessing city # 28: Punta Arenas
# Accessing city # 29: Belmonte
# Accessing city # 30: Seoul
# Accessing city # 31: Whitianga
# Accessing city # 32: Bredasdorp
# Accessing city # 33: Honningsvag
# Accessing city # 34: Usinsk
# Accessing city # 35: Pombas
# Accessing city # 36: San Jeronimo
# Accessing city # 37: Winnemucca
# Accessing city # 38: Busselton
# Accessing city # 39: Victoria
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 39: Victoria
# Accessing city # 40: Hermanus
# Accessing city # 41: Copiapo
# Accessing city # 42: Lebu
# Accessing city # 43: San Joaquin
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 43: San Joaquin
# Accessing city # 44: Nizhniy Kuranakh
# Accessing city # 45: Boca do Acre
# Accessing city # 46: Hobart
# Accessing city # 47: Kochi
# Accessing city # 48: Kutum
# Accessing city # 49: Barrow
# Accessing city # 50: Simao
# Accessing city # 51: Dubuque
# Accessing city # 52: Mar del Plata
# Accessing city # 53: Alofi
# Accessing city # 54: Bluff
# Accessing city # 55: Codrington
# Accessing city # 56: Pasighat
# Accessing city # 57: Tuktoyaktuk
# Accessing city # 58: Nikolskoye
# Accessing city # 59: Kurilsk
# Accessing city # 60: Jamestown
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 60: Jamestown
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 60: Jamestown
# Accessing city # 61: Port Hedland
# Accessing city # 62: Hendek
# Accessing city # 63: Salalah
# Accessing city # 64: Oussouye
# Accessing city # 65: Antalaha
# Accessing city # 66: Mataura
# Accessing city # 67: New Norfolk
# Accessing city # 68: Puerto Ayora
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 68: Puerto Ayora
# Accessing city # 69: Airai
# Accessing city # 70: Rikitea
# Accessing city # 71: Vitim
# Accessing city # 72: Avarua
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 72: Avarua
# Accessing city # 73: Port Alfred
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 73: Port Alfred
# Accessing city # 74: Gat
# Accessing city # 75: Coquimbo
# Accessing city # 76: Provideniya
# Accessing city # 77: Rawson
# Accessing city # 78: Caravelas
# Accessing city # 79: Miramar
# Accessing city # 80: Haldibari
# Accessing city # 81: Jiayuguan
# Accessing city # 82: Worthington
# Accessing city # 83: Kamina
# Accessing city # 84: Sao Filipe
# Accessing city # 85: Severo-Kurilsk
# Accessing city # 86: Arraial do Cabo
# Accessing city # 87: Taoudenni
# Accessing city # 88: Urgut
# Accessing city # 89: Avera
# Accessing city # 90: Caraguatatuba
# Accessing city # 91: Allapalli
# Accessing city # 92: Lavrentiya
# Accessing city # 93: Yellowknife
# Accessing city # 94: Tibati
# Accessing city # 95: Saint-Augustin
# Accessing city # 96: Saint-Philippe
# Accessing city # 97: Susehri
# Accessing city # 98: Swedru
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 98: Swedru
# Accessing city # 99: Tocopilla
# Accessing city # 100: Lagoa
# Accessing city # 101: Eyl
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 101: Eyl
# Accessing city # 102: Norman Wells
# Accessing city # 103: Qaanaaq
# Accessing city # 104: Halifax
# Accessing city # 105: Cherskiy
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 105: Cherskiy
# Accessing city # 106: Itaituba
# Accessing city # 107: Padang
# Accessing city # 108: Iqaluit
# Accessing city # 109: Goderich
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 109: Goderich
# Accessing city # 110: Havelock
# Accessing city # 111: Mabaruma
# Accessing city # 112: Cape Coast
# Accessing city # 113: Hudson Bay
# Accessing city # 114: Butaritari
# Accessing city # 115: Wukari
# Accessing city # 116: Flinders
# Accessing city # 117: Klaksvik
# Accessing city # 118: Lianzhou
# Accessing city # 119: Dikson
# Accessing city # 120: Hami
# Accessing city # 121: Pisco
# Accessing city # 122: Busayra
# Accessing city # 123: Barcelos
# Accessing city # 124: Geraldton
# Accessing city # 125: Longyearbyen
# Accessing city # 126: Tasiilaq
# Accessing city # 127: Belaya Gora
# Accessing city # 128: Kirakira
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 128: Kirakira
# Accessing city # 129: Ust-Nera
# Accessing city # 130: Katsuura
# Accessing city # 131: Clyde River
# Accessing city # 132: Mareeba
# Accessing city # 133: Chokurdakh
# Accessing city # 134: Palmer
# Accessing city # 135: Margate
# Accessing city # 136: Nouadhibou
# Accessing city # 137: Touros
# Accessing city # 138: Maturin
# Accessing city # 139: Bonthe
# Accessing city # 140: Broken Hill
# Accessing city # 141: Sangar
# Accessing city # 142: Miraflores
# Accessing city # 143: Ilulissat
# Accessing city # 144: Chabahar
# Accessing city # 145: Georgetown
# Accessing city # 146: Hohhot
# Accessing city # 147: Santa Ana
# Accessing city # 148: Hamilton
# Accessing city # 149: Terenos
# Accessing city # 150: Guerrero Negro
# Accessing city # 151: Kuala Terengganu
# Accessing city # 152: Thompson
# Accessing city # 153: Bambous Virieux
# Accessing city # 154: Bage
# Accessing city # 155: Berlevag
# Accessing city # 156: Tuatapere
# Accessing city # 157: Nelson Bay
# Accessing city # 158: Tabou
# Accessing city # 159: Namibe
# Accessing city # 160: Pevek
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 160: Pevek
# Accessing city # 161: Saint George
# Accessing city # 162: Peleduy
# Accessing city # 163: Nandu
# Accessing city # 164: Ribeira Grande
# Accessing city # 165: Nyzhnya Duvanka
# Accessing city # 166: Weihai
# Accessing city # 167: Port Elizabeth
# Accessing city # 168: Khategaon
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 168: Khategaon
# Accessing city # 169: Tambacounda
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 169: Tambacounda
# Accessing city # 170: San Jose
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 170: San Jose
# Accessing city # 171: Amapa
# Accessing city # 172: Banda Aceh
# Accessing city # 173: La Ronge
# Accessing city # 174: Oyo
# Accessing city # 175: Pelym
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 175: Pelym
# Accessing city # 176: Shakhunya
# Accessing city # 177: Zhigansk
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 177: Zhigansk
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 177: Zhigansk
# Accessing city # 178: Khandbari
# Accessing city # 179: Mapiripan
# Accessing city # 180: Narsaq
# Accessing city # 181: Makakilo City
# Accessing city # 182: Porbandar
# Accessing city # 183: Joshimath
# Accessing city # 184: Namatanai
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 184: Namatanai
# Accessing city # 185: Khandyga
# Accessing city # 186: Shorkot
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 186: Shorkot
# Accessing city # 187: Birao
# Accessing city # 188: Chuy
# Accessing city # 189: Deniliquin
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 189: Deniliquin
# Accessing city # 190: Lata
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 190: Lata
# Accessing city # 191: Takoradi
# Accessing city # 192: Levelland
# Accessing city # 193: Meulaboh
# Accessing city # 194: Paungde
# Accessing city # 195: Talara
# Accessing city # 196: Kholodnyy
# Accessing city # 197: Tandil
# Accessing city # 198: Paracuru
# Accessing city # 199: Sharjah
# Accessing city # 200: Ostrovnoy
# Accessing city # 201: Saskylakh
# Accessing city # 202: Lastoursville
# Accessing city # 203: Khatanga
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 203: Khatanga
# Accessing city # 204: Rorvik
# Accessing city # 205: Hasaki
# Accessing city # 206: Necochea
# Accessing city # 207: Saldanha
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 207: Saldanha
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 207: Saldanha
# Accessing city # 208: Jijiga
# Accessing city # 209: Jiaocheng
# Accessing city # 210: Kavaratti
# Accessing city # 211: Den Helder
# Accessing city # 212: Muros
# Accessing city # 213: Batemans Bay
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 213: Batemans Bay
# Accessing city # 214: Lidkoping
# Accessing city # 215: Beringovskiy
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 215: Beringovskiy
# Accessing city # 216: Shalinskoye
# Accessing city # 217: Kizema
# Accessing city # 218: Tecoanapa
# Accessing city # 219: Haradok
# Accessing city # 220: Upernavik
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 220: Upernavik
# Accessing city # 221: Nenjiang
# Accessing city # 222: Larsnes
# Accessing city # 223: Souillac
# Accessing city # 224: Cidreira
# Accessing city # 225: Ayan
# Accessing city # 226: Paracatu
# Accessing city # 227: Taltal
# Accessing city # 228: Jizan
# Accessing city # 229: Hope Mills
# Accessing city # 230: Pitimbu
# Accessing city # 231: Kizukuri
# Accessing city # 232: Areka
# City not found ... : KeyError: 'id' ... Skipping.
# Accessing city # 232: Areka
# Accessing city # 233: Oranjestad
# Accessing city # 234: Deputatskiy
# Accessing city # 235: Marawi
# Accessing city # 236: Jardim
# Accessing city # 237: Port Augusta

# %%
len(city_data)

# %%
city_data.head()

# %%
city_data.to_csv('city_data.csv')
