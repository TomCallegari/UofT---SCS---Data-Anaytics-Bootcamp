# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
from requests import get
from time import sleep
from pprint import pprint
from config import api_key
from datetime import datetime

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# %%
# Setup the cities iterator
city_iter = [str(i) for i in cities]

# Initialize needed objects
city_count = 0
city_data = pd.DataFrame()

# %%
# For loop through the cities iterator, pull needed data from the JSON request object
for city in city_iter:
    
    response = get('http://api.openweathermap.org/data/2.5/weather?q='
                   + city
                   + '&APPID='
                   + api_key).json()
    
    # Pause for 1.175 seconds (70.5 seconds for 60 requests) 
    # to ensure compliance with request rate of 60 calls per minute
    sleep(1.175)
    
    try:
        
        # Pull needed data from JSON response object and insert into a dictionary
        city_dict = {
            'city_id': response['id'],
            'name': response['name'],
            'country': response['sys']['country'],
            'longitude': response['coord']['lon'],
            'latitude': response['coord']['lat'],
            'cloudiness': response['clouds']['all'],
            'humidity': response['main']['humidity'],
            'temperature': response['main']['temp'],
            'wind_speed': response['wind']['speed'],
            'time': response['dt']
        }
        
        # Create a temporary single row dataframe with the current cities data
        temp_df = pd.DataFrame(city_dict, index = ['city']).set_index('city_id')  
        
        # Add the temporary dataframe row to the pre-intialized city_data DataFrame
        city_data = pd.concat([city_data, temp_df])
        
        # Add 1 for each city iteration to the city counter
        city_count += 1
        
        # Collect the current cities name
        city_name = city_dict['name']    
            
        # Re-intialise the city dictionary to be empty for the next interation
        city_dict = {}
    
    # Raise a KeyError if a cities JSON response does not include any of the needed data
    except KeyError as e:
        
        print(f'Skipping city ... : KeyError: {e} not found.') 
    
    print(f'Accessing city # {city_count} | {city_name}')
# Out:
# Accessing city # 1 | Rikitea
# Accessing city # 2 | Hobart
# Accessing city # 3 | Newport
# Accessing city # 4 | Mianyang
# Accessing city # 5 | Marawi
# Accessing city # 6 | Vaini
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 6 | Vaini
# Accessing city # 7 | Kodiak
# Accessing city # 8 | Jamestown
# Accessing city # 9 | Washington DC.
# Accessing city # 10 | Joshimath
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 10 | Joshimath
# Accessing city # 11 | Flin Flon
# Accessing city # 12 | Noumea
# Accessing city # 13 | Qaanaaq
# Accessing city # 14 | Gwanda
# Accessing city # 15 | Nanortalik
# Accessing city # 16 | Rafraf
# Accessing city # 17 | Mountain Home
# Accessing city # 18 | Busselton
# Accessing city # 19 | Cape Town
# Accessing city # 20 | Upernavik
# Accessing city # 21 | Bluff
# Accessing city # 22 | Castro
# Accessing city # 23 | Leningradskiy
# Accessing city # 24 | Cherskiy
# Accessing city # 25 | Kuytun
# Accessing city # 26 | Atuona
# Accessing city # 27 | Great Bend
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 27 | Great Bend
# Accessing city # 28 | Punta Arenas
# Accessing city # 29 | Kapaa
# Accessing city # 30 | Avarua
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 30 | Avarua
# Accessing city # 31 | Barrow
# Accessing city # 32 | Druzhba
# Accessing city # 33 | Ahipara
# Accessing city # 34 | Zyryanka
# Accessing city # 35 | Erzin
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 35 | Erzin
# Accessing city # 36 | Bagli
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 36 | Bagli
# Accessing city # 37 | Banamba
# Accessing city # 38 | Shahr-e Kord
# Accessing city # 39 | Samana
# Accessing city # 40 | Saint George
# Accessing city # 41 | Cockburn Town
# Accessing city # 42 | Kudahuvadhoo
# Accessing city # 43 | Moa
# Accessing city # 44 | Roseburg
# Accessing city # 45 | Hofn
# Accessing city # 46 | Nabire
# Accessing city # 47 | Verkhoyansk
# Accessing city # 48 | Hambantota
# Accessing city # 49 | New Norfolk
# Accessing city # 50 | Kysyl-Syr
# Accessing city # 51 | Ushuaia
# Accessing city # 52 | San Borja
# Accessing city # 53 | Lorengau
# Accessing city # 54 | Saskylakh
# Accessing city # 55 | Dabakala
# Accessing city # 56 | Ponta do Sol
# Accessing city # 57 | Lebu
# Accessing city # 58 | Whitehorse
# Accessing city # 59 | San Luis
# Accessing city # 60 | Mehtar Lam
# Accessing city # 61 | Lompoc
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 61 | Lompoc
# Accessing city # 62 | Saint-Philippe
# Accessing city # 63 | Pisco
# Accessing city # 64 | Dikson
# Accessing city # 65 | Vila Velha
# Accessing city # 66 | Puerto Ayora
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 66 | Puerto Ayora
# Accessing city # 67 | Tasiilaq
# Accessing city # 68 | Tirau
# Accessing city # 69 | Torbay
# Accessing city # 70 | Honiara
# Accessing city # 71 | Arraial do Cabo
# Accessing city # 72 | Banjar
# Accessing city # 73 | Cassia
# Accessing city # 74 | Ambovombe
# Accessing city # 75 | Albany
# Accessing city # 76 | Butaritari
# Accessing city # 77 | Port Elizabeth
# Accessing city # 78 | Port Macquarie
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 78 | Port Macquarie
# Accessing city # 79 | Tuktoyaktuk
# Accessing city # 80 | Kollam
# Accessing city # 81 | Seydi
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 81 | Seydi
# Accessing city # 82 | Puerto Colombia
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 82 | Puerto Colombia
# Accessing city # 83 | Necochea
# Accessing city # 84 | Hermanus
# Accessing city # 85 | Beringovskiy
# Accessing city # 86 | Vestmannaeyjar
# Accessing city # 87 | Valparaiso
# Accessing city # 88 | Nazira
# Accessing city # 89 | Hithadhoo
# Accessing city # 90 | Geraldton
# Accessing city # 91 | Slave Lake
# Accessing city # 92 | Camacupa
# Accessing city # 93 | Thompson
# Accessing city # 94 | Gambela
# Accessing city # 95 | Nauta
# Accessing city # 96 | Mataura
# Accessing city # 97 | Saint-Georges
# Accessing city # 98 | Hasaki
# Accessing city # 99 | Ponta Delgada
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 99 | Ponta Delgada
# Accessing city # 100 | Bredasdorp
# Accessing city # 101 | Bereznik
# Accessing city # 102 | Airai
# Accessing city # 103 | Kosh-Agach
# Accessing city # 104 | Ribeira Grande
# Accessing city # 105 | Vung Tau
# Accessing city # 106 | Rocha
# Accessing city # 107 | Lillooet
# Accessing city # 108 | Norman Wells
# Accessing city # 109 | Fort Nelson
# Accessing city # 110 | Mahebourg
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 110 | Mahebourg
# Accessing city # 111 | Oda
# Accessing city # 112 | Calvinia
# Accessing city # 113 | Sao Joao da Barra
# Accessing city # 114 | Unai
# Accessing city # 115 | Port Blair
# Accessing city # 116 | Tuskegee
# Accessing city # 117 | Kpandae
# Accessing city # 118 | Baruun-Urt
# Accessing city # 119 | Sur
# Accessing city # 120 | Mar del Plata
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 120 | Mar del Plata
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 120 | Mar del Plata
# Accessing city # 121 | Ichnya
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 121 | Ichnya
# Accessing city # 122 | La Ronge
# Accessing city # 123 | Pervomayskiy
# Accessing city # 124 | Corn Island
# Accessing city # 125 | Kemi
# Accessing city # 126 | Tilichiki
# Accessing city # 127 | Lensk
# Accessing city # 128 | Severo-Kurilsk
# Accessing city # 129 | Kaitangata
# Accessing city # 130 | Vostok
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 130 | Vostok
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 130 | Vostok
# Accessing city # 131 | Bambous Virieux
# Accessing city # 132 | Imeni Babushkina
# Accessing city # 133 | Presidencia Roque Saenz Pena
# Accessing city # 134 | Perleberg
# Accessing city # 135 | Ancud
# Accessing city # 136 | Kariai
# Accessing city # 137 | Khatanga
# Accessing city # 138 | Waipawa
# Accessing city # 139 | Kununurra
# Accessing city # 140 | Codrington
# Accessing city # 141 | Pasni
# Accessing city # 142 | Westport
# Accessing city # 143 | Hilo
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 143 | Hilo
# Accessing city # 144 | Jiangyou
# Accessing city # 145 | Kavieng
# Accessing city # 146 | Bethel
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 146 | Bethel
# Accessing city # 147 | Mkushi
# Accessing city # 148 | Narsaq
# Accessing city # 149 | Kali Vrisi
# Accessing city # 150 | Tura
# Accessing city # 151 | Faanui
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 151 | Faanui
# Accessing city # 152 | Krasne
# Accessing city # 153 | Arrifes
# Accessing city # 154 | Dembi Dolo
# Accessing city # 155 | Waddan
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 155 | Waddan
# Accessing city # 156 | Tahe
# Accessing city # 157 | Naze
# Accessing city # 158 | Ingham
# Accessing city # 159 | Beloha
# Accessing city # 160 | Teguise
# Accessing city # 161 | Gisborne
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 161 | Gisborne
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 161 | Gisborne
# Accessing city # 162 | Roald
# Accessing city # 163 | Kruisfontein
# Accessing city # 164 | Souillac
# Accessing city # 165 | Binzhou
# Accessing city # 166 | Cabo San Lucas
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 166 | Cabo San Lucas
# Accessing city # 167 | Chuy
# Accessing city # 168 | Sabha
# Accessing city # 169 | Ostrovnoy
# Accessing city # 170 | Aksarka
# Accessing city # 171 | Dakar
# Accessing city # 172 | Masumbwe
# Accessing city # 173 | Sao Felix do Xingu
# Accessing city # 174 | Kahului
# Accessing city # 175 | Rawson
# Accessing city # 176 | East London
# Accessing city # 177 | Luganville
# Accessing city # 178 | Fasa
# Accessing city # 179 | Provideniya
# Accessing city # 180 | Mahibadhoo
# Accessing city # 181 | Fortuna
# Accessing city # 182 | Kuznechnoye
# Accessing city # 183 | Luocheng
# Accessing city # 184 | Bonavista
# Accessing city # 185 | Muriti
# Accessing city # 186 | Alenquer
# Accessing city # 187 | Cotui
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 187 | Cotui
# Accessing city # 188 | Chaumont
# Accessing city # 189 | Khor
# Accessing city # 190 | Rio Gallegos
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 190 | Rio Gallegos
# Accessing city # 191 | Javanrud
# Accessing city # 192 | Carnarvon
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 192 | Carnarvon
# Accessing city # 193 | General Pico
# Accessing city # 194 | Osypenko
# Accessing city # 195 | Ceres
# Accessing city # 196 | Tessalit
# Accessing city # 197 | San Patricio
# Accessing city # 198 | Zinder
# Accessing city # 199 | Saldanha
# Accessing city # 200 | Longyearbyen
# Accessing city # 201 | Ninghai
# Accessing city # 202 | Lira
# Accessing city # 203 | Urucara
# Accessing city # 204 | Sibulan
# Accessing city # 205 | San Juan
# Accessing city # 206 | Katsuura
# Accessing city # 207 | Nikolskoye
# Accessing city # 208 | Sao Gabriel da Cachoeira
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 208 | Sao Gabriel da Cachoeira
# Accessing city # 209 | Sitka
# Accessing city # 210 | Pevek
# Accessing city # 211 | Cidreira
# Accessing city # 212 | Shubarkuduk
# Accessing city # 213 | Mitsamiouli
# Accessing city # 214 | Chippewa Falls
# Accessing city # 215 | Tuatapere
# Accessing city # 216 | Hope
# Accessing city # 217 | Ariquemes
# Accessing city # 218 | Itarema
# Accessing city # 219 | Sorland
# Accessing city # 220 | Lata
# Accessing city # 221 | Awbari
# Accessing city # 222 | Batticaloa
# Accessing city # 223 | Ilulissat
# Accessing city # 224 | Suoyarvi
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 224 | Suoyarvi
# Accessing city # 225 | Haines Junction
# Accessing city # 226 | Yurgamysh
# Accessing city # 227 | Port Lincoln
# Accessing city # 228 | Eskilstuna
# Accessing city # 229 | Riviere-au-Renard
# Accessing city # 230 | Gladstone
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 230 | Gladstone
# Accessing city # 231 | Half Moon Bay
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 231 | Half Moon Bay
# Accessing city # 232 | Sinnamary
# Accessing city # 233 | Gujan-Mestras
# Accessing city # 234 | Te Anau
# Accessing city # 235 | Tapes
# Accessing city # 236 | Champerico
# Accessing city # 237 | Dickinson
# Accessing city # 238 | Port Hedland
# Accessing city # 239 | Yerbogachen
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 239 | Yerbogachen
# Accessing city # 240 | Nikko
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 240 | Nikko
# Accessing city # 241 | Caravelas
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 241 | Caravelas
# Accessing city # 242 | Coquimbo
# Accessing city # 243 | Poum
# Accessing city # 244 | Port Alfred
# Accessing city # 245 | Vardo
# Accessing city # 246 | Iguape
# Accessing city # 247 | Severnoye
# Accessing city # 248 | Yaan
# Accessing city # 249 | Yago
# Accessing city # 250 | Morehead
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 250 | Morehead
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 250 | Morehead
# Accessing city # 251 | San Andres
# Accessing city # 252 | Taree
# Accessing city # 253 | Pont-Audemer
# Accessing city # 254 | Belyy Yar
# Accessing city # 255 | Bukene
# Accessing city # 256 | Changji
# Accessing city # 257 | Ratnagiri
# Accessing city # 258 | Lagoa
# Accessing city # 259 | Hamilton
# Accessing city # 260 | Ust-Kuyga
# Accessing city # 261 | Canon City
# Accessing city # 262 | Maniitsoq
# Accessing city # 263 | Cairns
# Accessing city # 264 | Xining
# Accessing city # 265 | Evora
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 265 | Evora
# Accessing city # 266 | Vila
# Accessing city # 267 | Mirnyy
# Accessing city # 268 | Bosobolo
# Accessing city # 269 | Gazanjyk
# Accessing city # 270 | Anuradhapura
# Accessing city # 271 | Grand-Santi
# Accessing city # 272 | Basco
# Accessing city # 273 | Dunedin
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 273 | Dunedin
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 273 | Dunedin
# Accessing city # 274 | Hualmay
# Accessing city # 275 | Taoudenni
# Accessing city # 276 | Mosetse
# Accessing city # 277 | Rajapur
# Accessing city # 278 | Buala
# Accessing city # 279 | Launceston
# Accessing city # 280 | Makakilo City
# Accessing city # 281 | Port-Gentil
# Accessing city # 282 | Clyde River
# Accessing city # 283 | Acapulco
# Accessing city # 284 | Yellowknife
# Accessing city # 285 | Puerto Maldonado
# Accessing city # 286 | Podporozhye
# Accessing city # 287 | Victoria
# Accessing city # 288 | Miri
# Accessing city # 289 | Yining
# Accessing city # 290 | Salalah
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 290 | Salalah
# Accessing city # 291 | Vila Franca do Campo
# Accessing city # 292 | Oxapampa
# Accessing city # 293 | Berlevag
# Accessing city # 294 | Broome
# Accessing city # 295 | Ust-Nera
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 295 | Ust-Nera
# Accessing city # 296 | Muli
# Accessing city # 297 | Camacha
# Accessing city # 298 | Limbang
# Accessing city # 299 | Aracati
# Accessing city # 300 | Kuragino
# Accessing city # 301 | Lavrentiya
# Accessing city # 302 | Acari
# Accessing city # 303 | Gardez
# Accessing city # 304 | Abu Samrah
# Accessing city # 305 | Pitimbu
# Accessing city # 306 | Dvinskoy
# Accessing city # 307 | Beyneu
# Accessing city # 308 | Conceicao do Araguaia
# Accessing city # 309 | Gra Liyia
# Accessing city # 310 | Penzance
# Accessing city # 311 | Kiknur
# Accessing city # 312 | Bose
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 312 | Bose
# Accessing city # 313 | Almeria
# Accessing city # 314 | Nampula
# Accessing city # 315 | Kiomboi
# Accessing city # 316 | Husavik
# Accessing city # 317 | Road Town
# Accessing city # 318 | Chettipalaiyam
# Accessing city # 319 | Jhanjharpur
# Accessing city # 320 | Dublin
# Accessing city # 321 | La Rochelle
# Accessing city # 322 | High Level
# Accessing city # 323 | Harnosand
# Accessing city # 324 | Shimoda
# Accessing city # 325 | Chokurdakh
# Accessing city # 326 | Mujiayingzi
# Accessing city # 327 | Shelburne
# Accessing city # 328 | Cavalcante
# Accessing city # 329 | Chifeng
# Accessing city # 330 | Phalaborwa
# Accessing city # 331 | Kavaratti
# Accessing city # 332 | Caceres
# Accessing city # 333 | Vanimo
# Accessing city # 334 | Esperance
# Accessing city # 335 | Kashan
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 335 | Kashan
# Accessing city # 336 | Bathsheba
# Accessing city # 337 | Lae
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 337 | Lae
# Accessing city # 338 | Denpasar
# Accessing city # 339 | Logan Lake
# Accessing city # 340 | Darhan
# Accessing city # 341 | Heishan
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 341 | Heishan
# Accessing city # 342 | Touros
# Accessing city # 343 | Shache
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 343 | Shache
# Accessing city # 344 | Fallon
# Accessing city # 345 | Comodoro Rivadavia
# Accessing city # 346 | Blagoyevo
# Accessing city # 347 | Wewak
# Accessing city # 348 | Hanzhong
# Accessing city # 349 | Deputatskiy
# Accessing city # 350 | Sandwick
# Accessing city # 351 | Purepero
# Accessing city # 352 | Tiksi
# Accessing city # 353 | Pulandian
# Accessing city # 354 | Hoquiam
# Accessing city # 355 | Sambava
# Accessing city # 356 | Bochnia
# Accessing city # 357 | Sukumo
# Accessing city # 358 | Stawell
# Accessing city # 359 | Vadu Motilor
# Accessing city # 360 | Sibu
# Accessing city # 361 | Bontang
# Accessing city # 362 | Romny
# Accessing city # 363 | Sao Filipe
# Accessing city # 364 | Camrose
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 364 | Camrose
# Accessing city # 365 | Portland
# Accessing city # 366 | Hami
# Accessing city # 367 | College
# Accessing city # 368 | Pangnirtung
# Accessing city # 369 | Mount Gambier
# Accessing city # 370 | Arlit
# Accessing city # 371 | Evensk
# Accessing city # 372 | Shingu
# Accessing city # 373 | Tawang
# Accessing city # 374 | Florence
# Accessing city # 375 | Mugur-Aksy
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 375 | Mugur-Aksy
# Accessing city # 376 | Broken Hill
# Accessing city # 377 | Mayumba
# Accessing city # 378 | Severo-Yeniseyskiy
# Accessing city # 379 | Aksu
# Accessing city # 380 | Umba
# Accessing city # 381 | Innisfail
# Accessing city # 382 | Anchorage
# Accessing city # 383 | Great Yarmouth
# Accessing city # 384 | Klaksvik
# Accessing city # 385 | Alakurtti
# Accessing city # 386 | Puerto Escondido
# Accessing city # 387 | Bereda
# Accessing city # 388 | Esik
# Accessing city # 389 | Araouane
# Accessing city # 390 | Gravdal
# Accessing city # 391 | Mehamn
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 391 | Mehamn
# Accessing city # 392 | Dwarka
# Accessing city # 393 | Guadalupe y Calvo
# Accessing city # 394 | Jumla
# Accessing city # 395 | Alta Floresta
# Accessing city # 396 | Seymchan
# Accessing city # 397 | Carutapera
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 397 | Carutapera
# Accessing city # 398 | Talnakh
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 398 | Talnakh
# Accessing city # 399 | Synya
# Accessing city # 400 | Banikoara
# Accessing city # 401 | Acandi
# Accessing city # 402 | Nandgaon
# Accessing city # 403 | Taonan
# Accessing city # 404 | Nsanje
# Accessing city # 405 | Kondinskoye
# Accessing city # 406 | Avera
# Accessing city # 407 | Ugoofaaru
# Accessing city # 408 | Dingle
# Accessing city # 409 | Jaca
# Accessing city # 410 | Itoman
# Accessing city # 411 | Kabare
# Accessing city # 412 | Cayenne
# Accessing city # 413 | Volot
# Accessing city # 414 | Gulf Gate Estates
# Accessing city # 415 | Biskamzha
# Accessing city # 416 | Aswan
# Accessing city # 417 | Altamira
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 417 | Altamira
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 417 | Altamira
# Accessing city # 418 | Burdur
# Accessing city # 419 | Volksrust
# Accessing city # 420 | Ngunguru
# Accessing city # 421 | Labuhan
# Accessing city # 422 | Flagstaff
# Accessing city # 423 | Alekseyevsk
# Accessing city # 424 | Matagami
# Accessing city # 425 | Yelniki
# Accessing city # 426 | Joconal
# Accessing city # 427 | Farmington
# Accessing city # 428 | Bauchi
# Accessing city # 429 | Cooma
# Accessing city # 430 | Bilma
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 430 | Bilma
# Accessing city # 431 | Cortes
# Accessing city # 432 | The Pas
# Accessing city # 433 | Alofi
# Accessing city # 434 | Vashkivtsi
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 434 | Vashkivtsi
# Accessing city # 435 | Lubaczow
# Accessing city # 436 | Dicabisagan
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 436 | Dicabisagan
# Accessing city # 437 | Funtua
# Accessing city # 438 | Tual
# Accessing city # 439 | Srednekolymsk
# Accessing city # 440 | Athni
# Accessing city # 441 | Katwa
# Accessing city # 442 | Constitucion
# Accessing city # 443 | Georgetown
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 443 | Georgetown
# Accessing city # 444 | Hit
# Accessing city # 445 | Asyut
# Accessing city # 446 | Stokmarknes
# Accessing city # 447 | Tomatlan
# Accessing city # 448 | Kaeo
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 448 | Kaeo
# Accessing city # 449 | Honningsvag
# Accessing city # 450 | Santiago de Cao
# Accessing city # 451 | Imamoglu
# Accessing city # 452 | Sakaiminato
# Accessing city # 453 | Kano
# Accessing city # 454 | Kangaatsiaq
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 454 | Kangaatsiaq
# Accessing city # 455 | Kenai
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 455 | Kenai
# Accessing city # 456 | Kuala Terengganu
# Accessing city # 457 | Kirovskiy
# Accessing city # 458 | Ukiah
# Accessing city # 459 | Namatanai
# Accessing city # 460 | Fare
# Accessing city # 461 | Kiunga
# Accessing city # 462 | Likhoslavl
# Accessing city # 463 | Grindavik
# Accessing city # 464 | The Valley
# Accessing city # 465 | Yeppoon
# Accessing city # 466 | Port Shepstone
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 466 | Port Shepstone
# Accessing city # 467 | Mayo
# Accessing city # 468 | Matola
# Accessing city # 469 | Anadyr
# Accessing city # 470 | Taitung
# Accessing city # 471 | Gigmoto
# Accessing city # 472 | Mazagao
# Accessing city # 473 | Ghanzi
# Accessing city # 474 | Douentza
# Accessing city # 475 | Bukan
# Accessing city # 476 | Paamiut
# Accessing city # 477 | Zhezkazgan
# Accessing city # 478 | Aljezur
# Accessing city # 479 | Eyl
# Accessing city # 480 | Nianzishan
# Accessing city # 481 | Navrongo
# Accessing city # 482 | Marzuq
# Accessing city # 483 | Kamaishi
# Accessing city # 484 | La Asuncion
# Accessing city # 485 | Neiafu
# Accessing city # 486 | Dzhebariki-Khaya
# Accessing city # 487 | Buraydah
# Accessing city # 488 | Kralendijk
# Accessing city # 489 | Vyara
# Accessing city # 490 | Nyurba
# Accessing city # 491 | Kitakami
# Accessing city # 492 | Pacific Grove
# Accessing city # 493 | Ust-Maya
# Accessing city # 494 | Canutama
# Accessing city # 495 | Bushehr
# Accessing city # 496 | Rochegda
# Accessing city # 497 | Nouadhibou
# Accessing city # 498 | Tsabong
# Accessing city # 499 | Kulhudhuffushi
# Accessing city # 500 | Chicama
# Accessing city # 501 | Kasongo-Lunda
# Accessing city # 502 | Sidi Ali
# Accessing city # 503 | Ouesso
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 503 | Ouesso
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 503 | Ouesso
# Accessing city # 504 | Lai
# Accessing city # 505 | Auki
# Accessing city # 506 | Concepcion del Oro
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 506 | Concepcion del Oro
# Accessing city # 507 | Tucuman
# Accessing city # 508 | Punta de Bombon
# Accessing city # 509 | Mattru
# Accessing city # 510 | Cumra
# Accessing city # 511 | Saint-Francois
# Accessing city # 512 | Porto Walter
# Accessing city # 513 | Freeport
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 513 | Freeport
# Accessing city # 514 | Watsa
# Accessing city # 515 | Umtata
# Accessing city # 516 | Daru
# Accessing city # 517 | Muzaffarabad
# Accessing city # 518 | Turbat
# Skipping city ... : KeyError: 'id' not found.
# Accessing city # 518 | Turbat
# Accessing city # 519 | Port Hardy
# Accessing city # 520 | Nieuw Nickerie
# Accessing city # 521 | Banka
# Accessing city # 522 | Beisfjord
# Accessing city # 523 | Minas
# Accessing city # 524 | Karratha
# Accessing city # 525 | Boueni
# Accessing city # 526 | Burley
# Accessing city # 527 | Omboue
# Accessing city # 528 | Sheridan
# Accessing city # 529 | Kaolinovo
# Accessing city # 530 | Vendome
# Accessing city # 531 | Meulaboh
# Accessing city # 532 | Cancun
# Accessing city # 533 | Voh
# Accessing city # 534 | Devarkonda
# Accessing city # 535 | Saquena
# Accessing city # 536 | Kirando
# Accessing city # 537 | Amberley
# Accessing city # 538 | Adrar
# Accessing city # 539 | Zhigansk
# Accessing city # 540 | Rosetta
# Accessing city # 541 | Preeceville
# Accessing city # 542 | Basiad
# Accessing city # 543 | Monterey
# Accessing city # 544 | Baraki Barak
# Accessing city # 545 | Requena
# Accessing city # 546 | Opuwo
# Accessing city # 547 | Xaxim
# Accessing city # 548 | Ternate
# Accessing city # 549 | Lucapa
# Accessing city # 550 | Alice Springs
# Accessing city # 551 | Rio Grande
# Accessing city # 552 | Sinnar
# Accessing city # 553 | Ust-Omchug
# Accessing city # 554 | San Cristobal

# %% [markdown]
# #### Post API call inspection

# %%
len(city_data)
# Out:
# 554

# %%
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 554 entries, 4030556 to 3652462
# Data columns (total 9 columns):
# name           554 non-null object
# country        554 non-null object
# longitude      554 non-null float64
# latitude       554 non-null float64
# cloudiness     554 non-null int64
# humidity       554 non-null int64
# temperature    554 non-null float64
# wind_speed     554 non-null float64
# time           554 non-null int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 43.3+ KB

# %%
city_data.sample(20)
# Out:
#                    name country  longitude  latitude  cloudiness  humidity  \
# city_id
# 2193968        Amberley      NZ     172.73    -43.15          62        93
# 317844            Cumra      TR      32.77     37.57          20        28
# 3991253        Purepero      MX    -102.02     19.92          90        93
# 3025892        Chaumont      FR       5.14     48.11           0        29
# 5975004      High Level      CA    -117.13     58.52          90        87
# 1648186         Bontang      ID     117.47      0.12         100        98
# 1733782        Victoria      BN     115.24      5.28          75        83
# 1214488        Meulaboh      ID      96.13      4.14         100        63
# 3383427  Nieuw Nickerie      SR     -56.99      5.94          32        80
# 2337542            Naze      NG       7.07      5.43         100        98
# 2517679         Fortuna      ES      -1.13     38.18           0        33
# 730651        Kaolinovo      BG      27.12     43.62          13        74
# 1090467          Boueni      YT      45.08    -12.90          20        74
# 3466165        Cidreira      BR     -50.22    -30.17         100        58
# 286621          Salalah      OM      54.10     17.01          20        84
# 2152659  Port Macquarie      AU     152.91    -31.43          75        93
# 4035715          Avarua      CK    -159.78    -21.21          73        69
# 3652764    Puerto Ayora      EC     -90.35     -0.74           5        74
# 2377457      Nouadhibou      MR     -17.03     20.93          25        64
# 779554      Honningsvag      NO      25.97     70.98          33        85
#
#          temperature  wind_speed        time
# city_id
# 2193968       277.86        2.10  1561388561
# 317844        302.07        5.70  1561388520
# 3991253       291.15        1.43  1561388264
# 3025892       304.89        2.60  1561388003
# 5975004       287.15        4.10  1561388218
# 1648186       296.80        1.24  1561388279
# 1733782       300.78        2.17  1561388164
# 1214488       302.70        0.37  1561388524
# 3383427       300.40        5.00  1561388537
# 2337542       296.20        2.99  1561387954
# 2517679       301.93        3.60  1561387992
# 730651        299.39        0.45  1561388550
# 1090467       300.15        3.60  1561388544
# 3466165       297.00        4.41  1561388041
# 286621        303.15        5.70  1561388168
# 2152659       284.65        2.10  1561387823
# 4035715       296.15        3.60  1561387747
# 3652764       296.50        3.75  1561387804
# 2377457       297.15        8.20  1561388498
# 779554        281.80        9.00  1561388425

# %% [markdown]
# #### Write to CSV

# %%
city_data.to_csv('city_data.csv')
