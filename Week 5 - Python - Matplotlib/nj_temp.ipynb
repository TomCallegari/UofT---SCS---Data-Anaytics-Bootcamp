# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = [39, 42, 51, 62, 72, 82, 86, 84, 77, 65, 55, 44]
months = np.arange(1, 13, 1)

# %%
cel = [(i - 32)*0.56 for i in temp]

# %%
plt.plot(months, temp, marker='+', color='blue', label='Fahrenheit')
plt.plot(months, cel, marker='s', color='red', label='Celsius')
plt.legend(loc='best')
plt.xlabel('Months')
plt.ylabel('Temperature in Degrees')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Temperature in Degrees')

# %%
plt.plot(months, temp)
plt.plot(months, cel)

# %%
plt.savefig('matplotlib_temp_example.png')
plt.show()
