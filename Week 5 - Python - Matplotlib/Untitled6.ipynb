# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Datasaurus_data.csv')

# %%
data = data.rename(columns={'55.3846': 'x', '97.1795': 'y'})

# %%
plt.scatter(data['x'], data['y'])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
