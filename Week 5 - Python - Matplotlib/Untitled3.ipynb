# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
users = [13000, 26000, 52000, 30000, 9000]
x = np.arange(len(users))

# %%
plt.bar(x, users, color='r', alpha=0.5, align='center')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <BarContainer object of 5 artists>

# %%
tick_locations = [value for value in x]
plt.xticks(tick_locations, ['Java', 'C++', 'Python', 'Ruby', 'Clojure'])
# Out:
# ([<matplotlib.axis.XTick at 0x1c775b75c18>,
#   <matplotlib.axis.XTick at 0x1c775aa7e80>,
#   <matplotlib.axis.XTick at 0x1c775f067f0>,
#   <matplotlib.axis.XTick at 0x1c775f0d518>,
#   <matplotlib.axis.XTick at 0x1c775f0db00>],
#  <a list of 5 Text xticklabel objects>)

# %%
plt.xlim(-0.75, len(x)-0.25)
# Out:
# (-0.75, 4.75)

# %%
plt.ylim(0, max(users)+500)
# Out:
# (0, 52500)

# %%
plt.title('Popularity of Programming Languages')
plt.ylabel('Number of Users')
plt.xlabel('')
