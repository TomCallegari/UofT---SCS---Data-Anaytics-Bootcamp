# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['Humans', 'Smurfs', 'Hobbits', 'Ninjas']
sizes = [220, 95, 80, 2000]
colors = ['red', 'orange', 'lightcoral', 'lightskyblue']
explode = [0.1, 0, 0, 0]

# %%
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# ([<matplotlib.patches.Wedge at 0x17b51610208>,
#   <matplotlib.patches.Wedge at 0x17b51610ba8>,
#   <matplotlib.patches.Wedge at 0x17b516205c0>,
#   <matplotlib.patches.Wedge at 0x17b51620f28>],
#  [Text(-1.1007595672664494, 0.4778371846888636, 'Humans'),
#   Text(-1.0999926979481953, -0.004008049482022066, 'Smurfs'),
#   Text(-1.070225988610212, -0.254197429773188, 'Hobbits'),
#   Text(1.0822283551054273, -0.19693092039037768, 'Ninjas')],
#  [Text(-0.6421097475720955, 0.2787383577351704, '9.2%'),
#   Text(-0.5999960170626519, -0.002186208808375672, '4.0%'),
#   Text(-0.5837596301510246, -0.13865314351264799, '3.3%'),
#   Text(0.5903063755120512, -0.10741686566747873, '83.5%')])

# %%
plt.axis('equal')
# Out:
# (-1.1889043116878248,
#  1.1097079655058293,
#  -1.1061045526123663,
#  1.1065567383506403)
